# %%
# Import required packages

import json
from pathlib import Path
import pprint

import starfile
from cellstar_db.models import (
    GeometricSegmentationInputData,
    ShapePrimitiveInputData,
    ShapePrimitiveKind,
    SphereInputParams,
)
from cellstar_preprocessor.flows.common import hex_to_rgba_normalized

# %%
# Define a function for parsing .star file content into geometric segmentation
# in format supported by Preprocessor (.json file conforming to specific data model)

def parse_single_star_file(
    path: Path,
    sphere_radius: float,
    sphere_color: list[float],
    pixel_size: float,
    star_file_coordinate_divisor: int,
    segmentation_id: str,
):
    lst: list[ShapePrimitiveInputData] = []
    df = starfile.read(str(path.resolve()))
    for index, row in df.iterrows():
        radius = sphere_radius
        color = sphere_color

        sp_input_data = ShapePrimitiveInputData(
            kind=ShapePrimitiveKind.sphere,
            parameters=SphereInputParams(
                id=index,
                center=(
                    row["rlnCoordinateX"] / star_file_coordinate_divisor * pixel_size,
                    row["rlnCoordinateY"] / star_file_coordinate_divisor * pixel_size,
                    row["rlnCoordinateZ"] / star_file_coordinate_divisor * pixel_size,
                ),
                color=color,
                radius=radius,
            ),
        )

        lst.append(sp_input_data)
    d = {0: lst}
    geometric_segmentation_input = GeometricSegmentationInputData(
        segmentation_id=segmentation_id, shape_primitives_input=d
    )

    return geometric_segmentation_input

# %%
# Initialize variables to run the function on the 1st .star file:

star_file_path = Path(
    '../../../../test-data/preprocessor/sample_segmentations/empiar/empiar-11756/rln_ribosome_bin1_tomo_649.star'
)
sphere_radius = 100.0
sphere_color_hex: str = 'FFFF00'
pixel_size = 7.84
star_file_coordinate_divisor = 4
geometric_segmentation_input_file_path = Path(
    '../../../../test-data/preprocessor/sample_segmentations/empiar/empiar-11756/geometric_segmentation_input_1.json'
)

# convert sphere color in hex to normalized rgba
sphere_color = hex_to_rgba_normalized(sphere_color_hex)
segmentation_id = 'ribosomes'

# %%
# Parse rln_ribosome_bin1_tomo_649.star file

converted = parse_single_star_file(
    path=star_file_path,
    sphere_radius=sphere_radius,
    sphere_color=sphere_color,
    pixel_size=pixel_size,
    star_file_coordinate_divisor=star_file_coordinate_divisor,
    segmentation_id=segmentation_id,
)

pp = pprint.PrettyPrinter(indent=4)
pp.pprint(converted.dict())
# Out:
# {   'segmentation_id': 'ribosomes',
#     'shape_primitives_input': {   0: [   {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   5662.44,
#                                                                              989.8,
#                                                                              1852.2),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 0,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   5897.64,
#                                                                              1679.72,
#                                                                              1742.44),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 1,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6148.5199999999995,
#                                                                              2840.04,
#                                                                              2212.84),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 2,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   5693.8,
#                                                                              6791.4,
#                                                                              1930.6),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 3,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6070.12,
#                                                                              3185.0,
#                                                                              2212.84),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 4,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   5458.599999999999,
#                                                                              252.84,
#                                                                              1679.72),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 5,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   5740.84,
#                                                                              378.28,
#                                                                              1130.92),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 6,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6054.44,
#                                                                              3232.04,
#                                                                              1695.3999999999999),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 7,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   7857.639999999999,
#                                                                              958.4399999999999,
#                                                                              1899.24),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 8,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6132.84,
#                                                                              315.56,
#                                                                              2009.0),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 9,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6038.76,
#                                                                              3294.7599999999998,
#                                                                              1946.28),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 10,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6948.2,
#                                                                              3702.44,
#                                                                              1428.84),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 11,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6948.2,
#                                                                              7779.24,
#                                                                              2589.16),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 12,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6179.88,
#                                                                              2228.52,
#                                                                              2212.84),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 13,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6446.44,
#                                                                              7857.639999999999,
#                                                                              2056.04),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 14,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   5740.84,
#                                                                              1256.36,
#                                                                              1867.8799999999999),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 15,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   7481.32,
#                                                                              5834.92,
#                                                                              1726.76),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 16,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   2134.44,
#                                                                              205.79999999999998,
#                                                                              1522.92),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 17,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   7120.68,
#                                                                              7779.24,
#                                                                              2965.48),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 18,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6211.24,
#                                                                              5991.72,
#                                                                              1914.92),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 19,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   4611.88,
#                                                                              1005.48,
#                                                                              1836.52),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 20,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   5678.12,
#                                                                              848.68,
#                                                                              1130.92),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 21,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   5489.96,
#                                                                              237.16,
#                                                                              1193.6399999999999),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 22,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   7340.2,
#                                                                              1726.76,
#                                                                              2212.84),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 23,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   2745.96,
#                                                                              2667.56,
#                                                                              1726.76),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 24,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6885.48,
#                                                                              2604.84,
#                                                                              2228.52),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 25,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6603.24,
#                                                                              7841.96,
#                                                                              2981.16),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 26,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   801.64,
#                                                                              5568.36,
#                                                                              1836.52),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 27,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6477.8,
#                                                                              158.76,
#                                                                              2024.68),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 28,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   7810.599999999999,
#                                                                              7653.8,
#                                                                              1946.28),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 29,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6979.5599999999995,
#                                                                              6697.32,
#                                                                              2855.72),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 30,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   7857.639999999999,
#                                                                              1507.24,
#                                                                              1413.16),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 31,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6070.12,
#                                                                              2495.08,
#                                                                              2181.48),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 32,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   7371.5599999999995,
#                                                                              3796.52,
#                                                                              1413.16),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 33,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   7857.639999999999,
#                                                                              5160.68,
#                                                                              2416.68),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 34,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6587.5599999999995,
#                                                                              958.4399999999999,
#                                                                              1272.04),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 35,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6948.2,
#                                                                              4282.6,
#                                                                              2212.84),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 36,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6822.76,
#                                                                              4078.7599999999998,
#                                                                              2432.36),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 37,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   7199.08,
#                                                                              3561.3199999999997,
#                                                                              1428.84),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 38,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   3169.32,
#                                                                              284.2,
#                                                                              1836.52),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 39,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6744.36,
#                                                                              7826.28,
#                                                                              2040.36),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 40,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   7293.16,
#                                                                              1914.92,
#                                                                              2181.48),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 41,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   4078.7599999999998,
#                                                                              2369.64,
#                                                                              1491.56),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 42,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   7057.96,
#                                                                              7763.5599999999995,
#                                                                              1930.6),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 43,
#                                                                'radius': 100.0}},
#                                          {   'kind': <ShapePrimitiveKind.sphere: 'sphere'>,
#                                              'parameters': {   'center': (   6289.64,
#                                                                              1036.84,
#                                                                              2103.08),
#                                                                'color': [   1.0,
#                                                                             1.0,
#                                                                             0.0,
#                                                                             1.0],
#                                                                'id': 44,
#                                                                'radius': 100.0}}]},
#     'time_units': None}

# %%
# Write the data for the 1st geometric segmentation into JSON file

with (geometric_segmentation_input_file_path).open("w") as fp:
    json.dump(converted.dict(), fp, indent=4)

# %%
# Change variables values to run the function on the rln_nucleosome_bin1_tomo_649.star file

star_file_path = Path(
    '../../../../test-data/preprocessor/sample_segmentations/empiar/empiar-11756/rln_nucleosome_bin1_tomo_649.star'
)
sphere_color_hex: str = 'FF0000'
geometric_segmentation_input_file_path = Path(
    '../../../../test-data/preprocessor/sample_segmentations/empiar/empiar-11756/geometric_segmentation_input_2.json'
)

# convert sphere color in hex to normalized rgba

sphere_color = hex_to_rgba_normalized(sphere_color_hex)
segmentation_id = 'nucleosomes'

# %%
# Parse rln_nucleosome_bin1_tomo_649.star file

converted = parse_single_star_file(
    path=star_file_path,
    sphere_radius=sphere_radius,
    sphere_color=sphere_color,
    pixel_size=pixel_size,
    star_file_coordinate_divisor=star_file_coordinate_divisor,
    segmentation_id=segmentation_id,
)

print(converted)
# Out:
# segmentation_id='nucleosomes' shape_primitives_input={0: [ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=0, color=[1.0, 0.0, 0.0, 1.0], center=(2353.96, 5066.599999999999, 2432.36), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=1, color=[1.0, 0.0, 0.0, 1.0], center=(2416.68, 4368.84, 2071.72), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=2, color=[1.0, 0.0, 0.0, 1.0], center=(5215.5599999999995, 1852.2, 1585.6399999999999), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=3, color=[1.0, 0.0, 0.0, 1.0], center=(4345.32, 401.8, 1671.8799999999999), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=4, color=[1.0, 0.0, 0.0, 1.0], center=(4392.36, 2738.12, 1805.1599999999999), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=5, color=[1.0, 0.0, 0.0, 1.0], center=(5082.28, 2322.6, 1946.28), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=6, color=[1.0, 0.0, 0.0, 1.0], center=(4674.6, 4282.6, 2095.24), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=7, color=[1.0, 0.0, 0.0, 1.0], center=(4682.44, 3443.72, 1554.28), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=8, color=[1.0, 0.0, 0.0, 1.0], center=(4298.28, 260.68, 1593.48), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=9, color=[1.0, 0.0, 0.0, 1.0], center=(1342.6, 7920.36, 2291.24), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=10, color=[1.0, 0.0, 0.0, 1.0], center=(4298.28, 6932.5199999999995, 2385.32), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=11, color=[1.0, 0.0, 0.0, 1.0], center=(1146.6, 5756.5199999999995, 2267.72), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=12, color=[1.0, 0.0, 0.0, 1.0], center=(4219.88, 2471.56, 1632.68), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=13, color=[1.0, 0.0, 0.0, 1.0], center=(2322.6, 4188.5199999999995, 2314.7599999999998), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=14, color=[1.0, 0.0, 0.0, 1.0], center=(825.16, 3867.08, 1938.44), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=15, color=[1.0, 0.0, 0.0, 1.0], center=(1217.16, 6854.12, 2220.68), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=16, color=[1.0, 0.0, 0.0, 1.0], center=(2291.24, 2887.08, 1828.68), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=17, color=[1.0, 0.0, 0.0, 1.0], center=(4361.0, 3600.52, 1813.0), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=18, color=[1.0, 0.0, 0.0, 1.0], center=(4894.12, 2949.7999999999997, 2071.72), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=19, color=[1.0, 0.0, 0.0, 1.0], center=(1491.56, 6203.4, 2267.72), radius=100.0)), ShapePrimitiveInputData(kind=<ShapePrimitiveKind.sphere: 'sphere'>, parameters=SphereInputParams(id=20, color=[1.0, 0.0, 0.0, 1.0], center=(5239.08, 2393.16, 1593.48), radius=10 ...

# %%
# Write the data for the 2nd geometric segmentation into JSON file

with (geometric_segmentation_input_file_path).open("w") as fp:
    json.dump(converted.dict(), fp, indent=4)
